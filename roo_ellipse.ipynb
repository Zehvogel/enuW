# %%
import ROOT
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x66efbe0

# %%
e = ROOT.RooEllipse("", 0., 0., 3.550817981023924e-05, 4.2169818515941897e-05, -0.9792325421012014, 5000)
c = ROOT.TCanvas()
e.SetTitle(";#Deltag'_{1,Z}; #Delta#kappa'_{#gamma}")
e.Draw("al")
c.Draw()
# c.SaveAs("ellipse.pdf")
