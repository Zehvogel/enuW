# %%
import ROOT
# comment out to make black line at y == 0 in the last plot disappear
ROOT.TH1.SetDefaultSumw2()
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x7f43270

# %%
# %jsroot on
e = ROOT.RooEllipse("", 0., 0., 1.5879812e-3, 3.97629817e-3, -0.17, 5000)
c = ROOT.TCanvas()
e.SetTitle(";#Deltag_{1,Z}; #Delta#kappa_{#gamma}")
e.Draw("al")
c.Draw()
# Out:
# <div id="root_plot_1737461475201" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1737461475201(Core) {
# ...

# %%
# %jsroot off
c.Draw()

# %%
e2 = ROOT.RooEllipse("", 5.e-4, -5.e-4, 1.5879812e-3, 3.97629817e-3, -0.17, 5000)
mg = ROOT.TMultiGraph()
mg.Add(e)
mg.Add(e2)

# %%
c2 = ROOT.TCanvas()
mg.Draw("al")
c2.Draw()
